# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MA-1305/Project_Mahin-1305/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# My Lane: Content Refresh Prioritization
#
# ML Task Type: Classification
#
# The goal is to classify pages that are likely to decline in traffic and identify which pages should be refreshed first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Target:
#
# The target is whether a page is declining or not (trend_direction).
#
# This target helps identify pages that may require content updates.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Success Metric:
#
# A useful success metric is Precision@50 because it measures how many of the highest-priority recommended pages are actually declining.
#
# A higher Precision@50 means better recommendations for content refresh.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# !git clone https://github.com/MA-1305/Project_Mahin-1305.git
# %cd Project_Mahin-1305

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(df.head())

print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# Cloning into 'Project_Mahin-1305'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 135 (delta 48), reused 96 (delta 30), pack-reused 0 (from 0)
# Receiving objects: 100% (135/135), 1.85 MiB | 5.27 MiB/s, done.
# Resolving deltas: 100% (48/48), done.
# /content/Project_Mahin-1305/Project_Mahin-1305/Project_Mahin-1305/Project_Mahin-1305
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# ...

# %% [markdown]
# Unit of Analysis:
#
# Each row represents one content page.
#
# The model analyzes information about each page to determine whether it should be refreshed.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# A fixed rule considers only one or two conditions.
#
# Machine learning can evaluate multiple features together, such as CTR, average position, impressions, and content age, to provide better recommendations.
#
# The output supports content teams in deciding which pages to refresh first.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
