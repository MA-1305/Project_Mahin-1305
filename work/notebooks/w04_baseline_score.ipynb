# %% [markdown]
# # ML-07 — Baseline Action Score and Top-20 Review
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MA-1305/Project_Mahin-1305/blob/main/work/notebooks/w04_baseline_score.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My rule and its reason codes
#
# *Write the rule in plain words first. Then the reason codes it can output.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Rule:
#
# Rank pages using observable refresh-opportunity signals. Higher scores should indicate pages that deserve earlier human review.
#
# The baseline considers visibility, freshness risk, position opportunity, and content depth.
#
# Reason codes:
#
# - stale_visible_page
# - declining_with_demand
# - thin_visible_page
# - page_one_decay_risk
# - low_ctr_visible_page
# - low_engagement_visible_page
#
# The baseline is a decision-support ranking, not proof that refreshing a page will improve performance.

# %% [markdown]
# ## 2. Build the ranked queue (writes the CSV)
#
# *Code the score, rank everything, write work/outputs/baseline_action_score.csv.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# !git clone https://github.com/MA-1305/Project_Mahin-1305.git /content/Project_Mahin-1305
# Out:
# fatal: destination path '/content/Project_Mahin-1305' already exists and is not an empty directory.

# %%
from pathlib import Path

data_path = Path(
    "/content/Project_Mahin-1305/data/raw/content_refresh_anonymized.csv"
)

print("File exists:", data_path.exists())
print("File path:", data_path)
# Out:
# File exists: True
# File path: /content/Project_Mahin-1305/data/raw/content_refresh_anonymized.csv

# %%
data_path = Path(
    "/content/Project_Mahin-1305/data/raw/content_refresh_anonymized.csv"
)

df = pd.read_csv(data_path)

# %% [markdown]
# I will create a baseline action score using my selected signals. Pages with higher scores will be ranked higher for review and recommended action.

# %% [markdown]
# ## 3. Top-20 review
#
# *For each of the top 20: action, reason code, confidence note, and what would make it wrong.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The top 20 pages are the highest-ranked pages under the transparent baseline score. Each page should be reviewed using its reason code and supporting signals.
#
# A recommendation can be wrong because of seasonality, consolidation, low-volume noise, incomplete measurement, or a page that was recently changed.

# %% [markdown]
# ## 4. Weak picks + leakage check
#
# *Which picks look wrong and why? Confirm no product flags or future windows leaked in.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Weak picks are pages that receive a lower baseline score or have weak evidence for action.
#
# The baseline uses observable current-window signals and does not use the model output or product decision flags. Target-derived and future information are excluded from the baseline.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
