# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MA-1305/Project_Mahin-1305/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# My Lane: Content Refresh Prioritization
#
# I want to identify pages that are likely to lose traffic and should be refreshed first. This lane is useful because updating the right pages can help improve website performance and avoid spending time on pages that do not need changes.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Decide which pages should be reviewed first for content refresh.
#
# Action: Content editors can review the highest-priority pages and decide whether to refresh, expand, monitor, or leave them unchanged.
#
# Cost of a wrong call: A false positive can waste editing time, while a false negative can cause an important page to be missed.
#
# Why ML can help: Several signals such as visibility, CTR, position, content age, engagement, and content depth can be considered together instead of relying on one fixed rule.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

from pathlib import Path
import pandas as pd

# Find the repository from the current Colab location
repo = Path.cwd()

while repo != repo.parent and not (repo / "data/raw/content_refresh_anonymized.csv").exists():
    repo = repo.parent

data_path = repo / "data/raw/content_refresh_anonymized.csv"

if not data_path.exists():
    # !git clone https://github.com/MA-1305/Project_Mahin-1305.git /content/Project_Mahin-1305
    repo = Path("/content/Project_Mahin-1305")
    data_path = repo / "data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(data_path)

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("Average CTR:", round(df["ctr"].mean(), 3))
print("Average Position:", round(df["avg_position"].mean(), 2))
# Out:
# fatal: destination path '/content/Project_Mahin-1305' already exists and is not an empty directory.
# Rows: 30000
# Columns: 44
# Average CTR: 0.511
# Average Position: 16.34

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project provides decision support based on patterns in the available dataset. The observations are based on the provided data only and do not prove cause and effect or predict Google's algorithm.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
